# %% [markdown]
# <a href="https://colab.research.google.com/github/R0g1n1-Pr174/Salary-Distribution-Comparison/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

np.random.seed(42)

dept_A = np.random.normal(loc=50000, scale=5000,size=30)
dept_B = np.random.normal(loc=60000, scale=6000,size=30)
print("Mean Salary Dept A:",round(np.mean(dept_A),2))
print("Mean Salary Dept B:",round(np.mean(dept_B),2))

t_start, p_value = stats.ttest_ind(dept_A, dept_B)

print("\nT-Statistic:",round(t_start,3))
print("P-Value:",round(p_value,4))

alpha = 0.05
if p_value < alpha:
    print(" ✅ Reject Null Hypothesis(Signicant Difference)")
else:
     print(" ❌ Fail to Reject Null Hypothesis(No Significant Difference)")

plt.figure(figsize=(8,5))
sns.kdeplot(dept_A, fill=True, label="Department A")
sns.kdeplot(dept_B, fill=True, label="Department B")

plt.axvline(np.mean(dept_A), linestyle="--")
plt.axvline(np.mean(dept_B), linestyle="--")

plt.title("Salary Distribution Comparison")
plt.legend()
plt.show()
# Out:
# Mean Salary Dept A: 49059.27
# Mean Salary Dept B: 59273.03
#
# T-Statistic: -7.798
# P-Value: 0.0
#  ✅ Reject Null Hypothesis(Signicant Difference)
